# %% [markdown]
# <a href="https://colab.research.google.com/github/veranika-izrailyan/python_practice/blob/main/Copy_of_Choosing_the_right_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practical Machine Learning
# ### Project: Model Selection

# %% [markdown]
# # Abstract

# %% [markdown]
# # Part 1: Business and Data Understanding

# %% [markdown]
# ### Q. Define the problem domain

# %%
# Use classification to identify if cancer is malign or benign in the cancer dataset

# %%
# azureml-core of version 1.0.72 or higher is required
# azureml-dataprep[pandas] of version 1.1.34 or higher is required

# !pip install azureml-core
from azureml.core import Workspace, Dataset

subscription_id = '9d78210e-1ac5-46b0-a4ba-7fbe656f98ae'
resource_group = 'project-resource'
workspace_name = 'my-project-ws'

workspace = Workspace(subscription_id, resource_group, workspace_name)

dataset = Dataset.get_by_name(workspace, name='breastcancer_data')
data = dataset.to_pandas_dataframe()
data.head()
# Out:
# ...
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code CZ87YXY3L to authenticate.
# You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.
#          id diagnosis  ...  symmetry_mean  fractal_dimension_mean
# 0    842302         M  ...         0.2419                 0.07871
# 1    842517         M  ...         0.1812                 0.05667
# 2  84300903         M  ...         0.2069                 0.05999
# 3  84348301         M  ...         0.2597                 0.09744
# 4  84358402         M  ...         0.1809                 0.05883
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Q. Identify candidate questions for your machine learning project

# %%
for col_name in data.columns:
  unique_values = data[col_name].value_counts()  
  unique_values_counted = unique_values.count()
  print(col_name + ' : ' + str(unique_values_counted) )
# Out:
# id : 1138
# diagnosis : 2
# radius_mean : 456
# texture_mean : 479
# perimeter_mean : 522
# area_mean : 539
# smoothness_mean : 474
# compactness_mean : 537
# concavity_mean : 537
# symmetry_mean : 432
# fractal_dimension_mean : 499

# %%
all_correlations = data.corr()
all_correlations
# Out:
#                               id  ...  fractal_dimension_mean
# id                      1.000000  ...               -0.036598
# radius_mean             0.052010  ...               -0.311631
# texture_mean            0.069534  ...               -0.076437
# perimeter_mean          0.050988  ...               -0.261477
# area_mean               0.067529  ...               -0.283110
# smoothness_mean        -0.009038  ...                0.584792
# compactness_mean        0.000067  ...                0.565369
# concavity_mean          0.034903  ...                0.336783
# symmetry_mean          -0.015412  ...                0.479921
# fractal_dimension_mean -0.036598  ...                1.000000
#
# [10 rows x 10 columns]

# %% [markdown]
# ### Q. Identify a suitable dataset for your canditate question(s)

# %% [markdown]
# using breastcancer_data dataset

# %% [markdown]
# ### Q. Generate a descriptive statistics report for the columns in your dataset

# %%
data.describe()
# Out:
#                  id  radius_mean  ...  symmetry_mean  fractal_dimension_mean
# count  1.138000e+03  1138.000000  ...    1138.000000             1138.000000
# mean   1.523243e+07    14.127292  ...       0.181162                0.062798
# std    8.965268e+07     3.522499  ...       0.027402                0.007057
# min    8.670000e+03     6.981000  ...       0.106000                0.049960
# 25%    9.299525e+04    11.700000  ...       0.161900                0.057700
# 50%    9.327950e+04    13.370000  ...       0.179200                0.061540
# 75%    9.060125e+05    15.780000  ...       0.195700                0.066120
# max    9.113205e+08    28.110000  ...       0.304000                0.097440
#
# [8 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure()
sns.heatmap(all_correlations, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Part 2: Data Preparation

# %% [markdown]
# ### Q. Discuss the following types of missing data and how they would be handled in reference to your dataset where applicable.

# %%
data.info()
# there are no non values in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1138 entries, 0 to 1137
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1138 non-null   int64
#  1   diagnosis               1138 non-null   object
#  2   radius_mean             1138 non-null   float64
#  3   texture_mean            1138 non-null   float64
#  4   perimeter_mean          1138 non-null   float64
#  5   area_mean               1138 non-null   float64
#  6   smoothness_mean         1138 non-null   float64
#  7   compactness_mean        1138 non-null   float64
#  8   concavity_mean          1138 non-null   float64
#  9   symmetry_mean           1138 non-null   float64
#  10  fractal_dimension_mean  1138 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 97.9+ KB

# %% [markdown]
# # Part 3: Model Selection

# %% [markdown]
# ![Screenshot (11).png](data:image/png;base64,...)

# %% [markdown]
# # Part 4: Model Evaluation

# %% [markdown]
# ### Q. Identify which of the statistical measures below are suitable for the evaluation of your model.

# %% [markdown]
# ![Screenshot (3).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (4).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (5).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (12).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (6).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (7).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (8).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (9).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (10).png](data:image/png;base64,...)

# %% [markdown]
# # Part 5: Stretch - Model Deployment

# %% [markdown]
# ### Q. Evaluate the open-source app framework for Machine Learning model deployment below in your own time.
#
# * https://streamlit.io/

# %%
import urllib.request
import json
import os
import ssl

def allowSelfSignedHttps(allowed):
    # bypass the server certificate verification on client side
    if allowed and not os.environ.get('PYTHONHTTPSVERIFY', '') and getattr(ssl, '_create_unverified_context', None):
        ssl._create_default_https_context = ssl._create_unverified_context

allowSelfSignedHttps(True) # this line is needed if you use self-signed certificate in your scoring service.

# Request data goes here
data = {
}

body = str.encode(json.dumps(data))

url = 'http://19d28486-738a-4186-8264-0a87147acd13.eastus.azurecontainer.io/score'
api_key = '' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
